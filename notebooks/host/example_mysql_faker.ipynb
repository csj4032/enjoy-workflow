# %%
import random
import time

import mysql.connector
from faker import Faker
from mysql.connector.abstracts import MySQLConnectionAbstract
from mysql.connector.pooling import PooledMySQLConnection

# %%
def get_engine(config) -> PooledMySQLConnection | MySQLConnectionAbstract:
    return mysql.connector.connect(**config)


def insert_loop(connection: PooledMySQLConnection | MySQLConnectionAbstract, faker: Faker, n: int):
    cursor = connection.cursor()
    customer_sql = "INSERT INTO customers (name, email, address, phone_number, company) VALUES (%s, %s, %s, %s, %s)"
    employee_sql = "INSERT INTO employees (name, department, salary) VALUES (%s, %s, %s)"
    department_sql = "INSERT INTO departments (name) VALUES (%s)"

    try:
        connection.start_transaction()
        for _ in range(n):
            customer_values = (faker.name(), faker.unique.email(), faker.address(), faker.phone_number(), faker.company())
            cursor.execute(customer_sql, customer_values)
            employee_values = (faker.name(), random.randint(1, 10), round(random.uniform(3000, 12000), 2))
            cursor.execute(employee_sql, employee_values)
            department_values = (faker.job()[:50],)
            cursor.execute(department_sql, department_values)
            connection.commit()
            time.sleep(0.1)
        print(f"✅ customers/employees 각각 {n}건 INSERT 완료")
    except Exception as e:
        connection.rollback()
        print("❌ rollback:", e)
    finally:
        cursor.close()
        connection.close()

# %%
insert_loop(get_engine({"host": "mysql-primary", "port": 3306, "user": "root", "password": "root", "database": "mmix", }), Faker(), 10000)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File /opt/miniconda3/envs/enjoy-workflow/lib/python3.12/site-packages/mysql/connector/connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Server shutdown in progress
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 15, in insert_loop(connection, faker, n)
#      14 customer_values = (faker.name(), faker.unique.email(), faker.address(), faker.phone_number(), faker.company())
# ---> 15 cursor.execute(customer_sql, customer_values)
#      16 employee_values = (faker.name(), random.randint(1, 10), round(random.uniform(3000, 12000), 2))
#
# File /opt/miniconda3/envs/enjoy-workflow/lib/python3.12/site-packages/mysql/connector/cursor_cext.py:353, in CMySQLCursor.execute(self, operation, params, map_results)
#     351 try:
#     352     self._handle_result(
# --> 353         self._connection.cmd_query(
#     354             self._stmt_partition["mappable_stmt"],
#     355             raw=self._raw,
#     356             buffered=self._buffered,
#     357             raw_as_string=self._raw_as_string,
#     358         )
#     359     )
#     360 except MySQLInterfaceError as err:
#
# File /opt/miniconda3/envs/enjoy-workflow/lib/python3.12/site-packages/mysql/connector/opentelemetry/context_propagation.py:106, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#     105 try:
# --> 106     result = method(cnx, *args, **kwargs)
#     107 finally:
#
# File /opt/miniconda3/envs/enjoy-workflow/lib/python3.12/site-packages/mysql/connector/connection_cext.py:781, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     780 if hasattr(err, "errno"):
# --> 781     raise get_mysql_exception(
#     782         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     783     ) from err
#     784 raise InterfaceError(str(err)) from err
#
# OperationalError: 1053 (08S01): Server shutdown in progress
#
# During handling of the above exception, another exception occurred:
#
# MySQLInterfaceError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 insert_loop(get_engine({"host": "mysql-primary", "port": 3306, "user": "root", "password": "root", "database": "mmix", }), Faker(), 10000)
#
# Cell In[2], line 24, in insert_loop(connection, faker, n)
#      22     print(f"✅ customers/employees 각각 {n}건 INSERT 완료")
#      23 except Exception as e:
# ---> 24     connection.rollback()
#      25     print("❌ rollback:", e)
#      26 finally:
#
# File /opt/miniconda3/envs/enjoy-workflow/lib/python3.12/site-packages/mysql/connector/connection_cext.py:611, in CMySQLConnection.rollback(self)
#     609 if self._cmysql:
#     610     self._cmysql.consume_result()
# --> 611     self._cmysql.rollback()
#
# MySQLInterfaceError: Lost connection to MySQL server during query
