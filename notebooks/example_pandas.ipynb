# %%
import pandas as pd

# %%
dataframe = pd.read_parquet('./data/customer.parquet')
dataframe.head(10)
# Out:
#    id name                    email   age signup_date
# 0   1  송지원           gi@example.net  20.0  2025-10-17
# 1   2  진지훈   yeonghyi76@example.org  35.0  2025-03-30
# 2   3  이경자      haeun87@example.com  46.0  2025-05-11
# 3   4  고지민  gimseohyeon@example.org  25.0  2025-12-27
# 4   5  안지민      areum87@example.net  63.0  2025-06-02
# 5   6  이경수         dhan@example.org  57.0  2025-11-07
# 6   7  최예준   yeongsun81@example.net  56.0  2025-10-24
# 7   8  박주원       ijihun@example.net  55.0  2025-03-23
# 8   9  윤성민    ihyeonsug@example.net  47.0  2025-12-11
# 9  10  김종수                     None  25.0  2025-10-12
