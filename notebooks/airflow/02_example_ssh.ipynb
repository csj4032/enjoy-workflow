# %%
from airflow.models import Variable
from airflow.providers.ssh.operators.ssh import SSHOperator
# Out:
# 2026-01-24T08:28:44.856909Z [debug    ] Setting up DB connection pool (PID 1063) [airflow.settings] loc=settings.py:394
# 2026-01-24T08:28:44.857492Z [debug    ] settings.prepare_engine_args(): Using pool settings. pool_size=5, max_overflow=10, pool_recycle=1800, pid=1063 [airflow.settings] loc=settings.py:500
# 2026-01-24T08:28:45.176736Z [debug    ] registering decimal.Decimal for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T08:28:45.177361Z [debug    ] registering decimal.Decimal for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T08:28:45.177823Z [debug    ] registering builtins.frozenset for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T08:28:45.178177Z [debug    ] registering builtins.set for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T08:28:45.178736Z [debug    ] registering builtins.tuple for serialization [airflow.serialization.serde] loc=serde.py:375
# ...

# %%
SSHOperator(task_id="run_remote", ssh_conn_id=Variable.get("mmix-dbt-server-ssh-conn-id"), command="whoami")
# Out:
# <Task(SSHOperator): run_remote>
