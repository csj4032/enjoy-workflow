# %%
from airflow.models import Variable
from airflow.providers.ssh.operators.ssh import SSHOperator
# Out:
# 2026-01-24T10:37:58.168864Z [debug    ] Setting up DB connection pool (PID 3116) [airflow.settings] loc=settings.py:394
# 2026-01-24T10:37:58.169422Z [debug    ] settings.prepare_engine_args(): Using pool settings. pool_size=5, max_overflow=10, pool_recycle=1800, pid=3116 [airflow.settings] loc=settings.py:500
# 2026-01-24T10:37:58.189188Z [debug    ] Could not retrieve value from section database, for key sql_alchemy_engine_args. Skipping redaction of this conf. [airflow.configuration] loc=configuration.py:881
# 2026-01-24T10:37:58.544088Z [debug    ] registering decimal.Decimal for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.544809Z [debug    ] registering decimal.Decimal for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.546377Z [debug    ] registering builtins.frozenset for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.546795Z [debug    ] registering builtins.set for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.547111Z [debug    ] registering builtins.tuple for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.547460Z [debug    ] registering builtins.frozenset for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.547891Z [debug    ] registering builtins.set for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.548249Z [debug    ] registering builtins.tuple for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.548582Z [debug    ] registering builtins.frozenset for stringifying [airflow.serialization.serde] loc=serde.py:390
# 2026-01-24T10:37:58.549505Z [debug    ] registering builtins.set for stringifying [airflow.serialization.serde] loc=serde.py:390
# 2026-01-24T10:37:58.549856Z [debug    ] registering builtins.tuple for stringifying [airflow.serialization.serde] loc=serde.py:390
# 2026-01-24T10:37:58.550759Z [debug    ] registering datetime.date for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.551032Z [debug    ] registering datetime.datetime for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.551522Z [debug    ] registering datetime.timedelta for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.551969Z [debug    ] registering pendulum.datetime.DateTime for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.552474Z [debug    ] registering datetime.date for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.552825Z [debug    ] registering datetime.datetime for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.553327Z [debug    ] registering datetime.timedelta for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.553722Z [debug    ] registering pendulum.datetime.DateTime for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.555113Z [debug    ] registering deltalake.table.DeltaTable for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.555959Z [debug    ] registering deltalake.table.DeltaTable for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.556965Z [debug    ] registering deltalake.table.DeltaTable for stringifying [airflow.serialization.serde] loc=serde.py:390
# 2026-01-24T10:37:58.558500Z [debug    ] registering pyiceberg.table.Table for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.559304Z [debug    ] registering pyiceberg.table.Table for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.559816Z [debug    ] registering pyiceberg.table.Table for stringifying [airflow.serialization.serde] loc=serde.py:390
# 2026-01-24T10:37:58.560914Z [debug    ] registering kubernetes.client.models.v1_resource_requirements.V1ResourceRequirements for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.561339Z [debug    ] registering kubernetes.client.models.v1_pod.V1Pod for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.562235Z [debug    ] registering numpy.int8 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.562848Z [debug    ] registering numpy.int16 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.563382Z [debug    ] registering numpy.int32 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.564052Z [debug    ] registering numpy.int64 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.564381Z [debug    ] registering numpy.uint8 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.564722Z [debug    ] registering numpy.uint16 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.565412Z [debug    ] registering numpy.uint32 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.565828Z [debug    ] registering numpy.uint64 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.566233Z [debug    ] registering numpy.float64 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.566630Z [debug    ] registering numpy.float32 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.567286Z [debug    ] registering numpy.float16 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.567919Z [debug    ] registering numpy.complex128 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.568332Z [debug    ] registering numpy.complex64 for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.568734Z [debug    ] registering numpy.bool for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.569174Z [debug    ] registering numpy.bool_ for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.569596Z [debug    ] registering numpy.int8 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.569900Z [debug    ] registering numpy.int16 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.570521Z [debug    ] registering numpy.int32 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.570981Z [debug    ] registering numpy.int64 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.571520Z [debug    ] registering numpy.uint8 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.571784Z [debug    ] registering numpy.uint16 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.572035Z [debug    ] registering numpy.uint32 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.572404Z [debug    ] registering numpy.uint64 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.572993Z [debug    ] registering numpy.float64 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.573414Z [debug    ] registering numpy.float32 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.573808Z [debug    ] registering numpy.float16 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.574961Z [debug    ] registering numpy.complex128 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.575471Z [debug    ] registering numpy.complex64 for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.576179Z [debug    ] registering numpy.bool for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.577253Z [debug    ] registering numpy.bool_ for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.578425Z [debug    ] registering pandas.core.frame.DataFrame for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.578814Z [debug    ] registering pandas.core.frame.DataFrame for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.580445Z [debug    ] registering pydantic.main.BaseModel for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.581088Z [debug    ] registering pydantic.main.BaseModel for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.581500Z [debug    ] registering pendulum.tz.timezone.FixedTimezone for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.582091Z [debug    ] registering pendulum.tz.timezone.Timezone for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.582431Z [debug    ] registering zoneinfo.ZoneInfo for serialization [airflow.serialization.serde] loc=serde.py:375
# 2026-01-24T10:37:58.582988Z [debug    ] registering pendulum.tz.timezone.FixedTimezone for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.583300Z [debug    ] registering pendulum.tz.timezone.Timezone for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.583591Z [debug    ] registering zoneinfo.ZoneInfo for deserialization [airflow.serialization.serde] loc=serde.py:382
# 2026-01-24T10:37:58.584470Z [debug    ] loading serializers took 40.737 seconds [airflow.serialization.serde] loc=serde.py:393
# 2026-01-24T10:37:58.631716Z [debug    ] Could not retrieve value from section database, for key sql_alchemy_conn_async. Skipping redaction of this conf. [airflow.configuration] loc=configuration.py:881
# 2026-01-24T10:37:58.633020Z [debug    ] Could not retrieve value from section core, for key asset_manager_kwargs. Skipping redaction of this conf. [airflow.configuration] loc=configuration.py:881

# %%
SSHOperator(task_id="run_remote", ssh_conn_id=Variable.get("mmix-dbt-server-ssh-conn-id"), command="whoami")
# Out:
# <Task(SSHOperator): run_remote>
